# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\admin\OneDrive\Desktop\Pandas\Customer Call List.xlsx")
df
# Out:
#     CustomerID First_Name     Last_Name    Phone_Number  \
# 0         1001      Bilbo       Baggins    123-545-5421
# 1         1002       Troy      ...Nadir    123-643-9775
# 2         1003      Jesse      /Pinkman             NaN
# 3         1004        Jim       Schrute    123-543-2345
# 4         1005        Jon          Snow  876-678-3469\t
# 5         1006       Robb     ..Swanson    304-762-2467
# 6         1007     Leslie        Winger             NaN
# 7         1008   Sherlock        Holmes    123-545-5421
# 8         1009    Gandalf           NaN             NaN
# 9         1010      Peter        Parker    123-545-5421
# 10        1011    Samwise        Gamgee             NaN
# 11        1012   Hermione    ...Granger             NaN
# 12        1013        Don       …Draper    123-543-2345
# 13        1014     Leslie         Knope    876-678-3469
# 14        1015       Toby  /Flenderson_  123-643-9775\t
# 15        1016        Ron       Weasley    123-545-5421
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#     CustomerID First_Name   Last_Name    Phone_Number  \
# 0         1001      Bilbo     Baggins    123-545-5421
# 1         1002       Troy       Nadir    123-643-9775
# 2         1003      Jesse     Pinkman             NaN
# 3         1004        Jim     Schrute    123-543-2345
# 4         1005        Jon        Snow  876-678-3469\t
# 5         1006       Robb     Swanson    304-762-2467
# 6         1007     Leslie      Winger             NaN
# 7         1008   Sherlock      Holmes    123-545-5421
# 8         1009    Gandalf         NaN             NaN
# 9         1010      Peter      Parker    123-545-5421
# 10        1011    Samwise      Gamgee             NaN
# 11        1012   Hermione     Granger             NaN
# 12        1013        Don     …Draper    123-543-2345
# 13        1014     Leslie       Knope    876-678-3469
# 14        1015       Toby  Flenderson  123-643-9775\t
# 15        1016        Ron     Weasley    123-545-5421
# ...

# %%
df.drop(columns = "Not_Useful_Column")
# Out:
#     CustomerID First_Name   Last_Name    Phone_Number  \
# 0         1001      Bilbo     Baggins    123-545-5421
# 1         1002       Troy       Nadir    123-643-9775
# 2         1003      Jesse     Pinkman             NaN
# 3         1004        Jim     Schrute    123-543-2345
# 4         1005        Jon        Snow  876-678-3469\t
# 5         1006       Robb     Swanson    304-762-2467
# 6         1007     Leslie      Winger             NaN
# 7         1008   Sherlock      Holmes    123-545-5421
# 8         1009    Gandalf         NaN             NaN
# 9         1010      Peter      Parker    123-545-5421
# 10        1011    Samwise      Gamgee             NaN
# 11        1012   Hermione     Granger             NaN
# 12        1013        Don     …Draper    123-543-2345
# 13        1014     Leslie       Knope    876-678-3469
# 14        1015       Toby  Flenderson  123-643-9775\t
# 15        1016        Ron     Weasley    123-545-5421
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name    Phone_Number  \
# 0         1001      Bilbo     Baggins    123-545-5421
# 1         1002       Troy       Nadir    123-643-9775
# 2         1003      Jesse     Pinkman             NaN
# 3         1004        Jim     Schrute    123-543-2345
# 4         1005        Jon        Snow  876-678-3469\t
# 5         1006       Robb     Swanson    304-762-2467
# 6         1007     Leslie      Winger             NaN
# 7         1008   Sherlock      Holmes    123-545-5421
# 8         1009    Gandalf         NaN             NaN
# 9         1010      Peter      Parker    123-545-5421
# 10        1011    Samwise      Gamgee             NaN
# 11        1012   Hermione     Granger             NaN
# 12        1013        Don     …Draper    123-543-2345
# 13        1014     Leslie       Knope    876-678-3469
# 14        1015       Toby  Flenderson  123-643-9775\t
# 15        1016        Ron     Weasley    123-545-5421
# ...

# %%
df.loc[:,"Last_Name"] =df["Last_Name"].str.lstrip("...")
df.loc[:,"Last_Name"] =df["Last_Name"].str.lstrip("/")
df.loc[:,"Last_Name"] =df["Last_Name"].str.rstrip("_")
df = df.drop(columns = "Not_Useful_Column")
df
# Out:
#     CustomerID First_Name   Last_Name    Phone_Number  \
# 0         1001      Bilbo     Baggins    123-545-5421
# 1         1002       Troy       Nadir    123-643-9775
# 2         1003      Jesse     Pinkman             NaN
# 3         1004        Jim     Schrute    123-543-2345
# 4         1005        Jon        Snow  876-678-3469\t
# 5         1006       Robb     Swanson    304-762-2467
# 6         1007     Leslie      Winger             NaN
# 7         1008   Sherlock      Holmes    123-545-5421
# 8         1009    Gandalf         NaN             NaN
# 9         1010      Peter      Parker    123-545-5421
# 10        1011    Samwise      Gamgee             NaN
# 11        1012   Hermione     Granger             NaN
# 12        1013        Don     …Draper    123-543-2345
# 13        1014     Leslie       Knope    876-678-3469
# 14        1015       Toby  Flenderson  123-643-9775\t
# 15        1016        Ron     Weasley    123-545-5421
# ...

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('Yes','Y')
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('No','N')
df["Paying Customer"] = df["Paying Customer"].str.replace('Yes','Y')
df["Paying Customer"] = df["Paying Customer"].str.replace('No','N')
df
# Out:
#     CustomerID First_Name   Last_Name    Phone_Number  \
# 0         1001      Bilbo     Baggins    123-545-5421
# 1         1002       Troy       Nadir    123-643-9775
# 2         1003      Jesse     Pinkman             NaN
# 3         1004        Jim     Schrute    123-543-2345
# 4         1005        Jon        Snow  876-678-3469\t
# 5         1006       Robb     Swanson    304-762-2467
# 6         1007     Leslie      Winger             NaN
# 7         1008   Sherlock      Holmes    123-545-5421
# 8         1009    Gandalf         NaN             NaN
# 9         1010      Peter      Parker    123-545-5421
# 10        1011    Samwise      Gamgee             NaN
# 11        1012   Hermione     Granger             NaN
# 12        1013        Don     …Draper    123-543-2345
# 13        1014     Leslie       Knope    876-678-3469
# 14        1015       Toby  Flenderson  123-643-9775\t
# 15        1016        Ron     Weasley    123-545-5421
# ...

# %%
#df = df.replace('N/a','')
#df = df.replace('NaN','')
df=df.fillna('')
for x in df.index:
    if df.loc[x, "Do_Not_Contact"] == 'Y':
        df.drop(x, inplace=True)
for x in df.index:
    if df.loc[x, "Phone_Number"] == '':
        df.drop(x, inplace=True)
df = df.reset_index(drop=True)
df
# Out:
#     CustomerID First_Name   Last_Name    Phone_Number  \
# 0         1001      Bilbo     Baggins    123-545-5421
# 1         1005        Jon        Snow  876-678-3469\t
# 2         1008   Sherlock      Holmes    123-545-5421
# 3         1010      Peter      Parker    123-545-5421
# 4         1013        Don     …Draper    123-543-2345
# 5         1014     Leslie       Knope    876-678-3469
# 6         1015       Toby  Flenderson  123-643-9775\t
# 7         1016        Ron     Weasley    123-545-5421
# 8         1017     Dwight       Scott  123-643-9775\t
# 9         1020       Luke   Skywalker    876|678|3469
# 10        1020       Luke   Skywalker    876|678|3469
# 11        1016        Ron     Weasley    123-545-5421
# 12        1003      Jesse     Pinkman      7066950392
# 13        1001      Bilbo     Baggins    123-545-5421
# 14        1010      Peter      Parker    123-545-5421
# 15        1013        Don      Draper    123-543-2345
#
# ...
